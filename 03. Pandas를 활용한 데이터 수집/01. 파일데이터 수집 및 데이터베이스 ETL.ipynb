# %% [markdown]
# # Pandas 라이브러리를 활용한 데이터 수집 및 저장

# %% [markdown]
# # 1. 파일 데이터 수집 및 저장

# %% [markdown]
# #### 라이브러리 선언

# %%
# mysql 접속을 위한 패키지 설치
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 43.7 MB/s eta 0:00:00
# ...

# %%
# 데이터 행과 열을 조작하는 라이브러리
import pandas as pd
# sql 데이터 수집 및 저장 라이브러리
from sqlalchemy import create_engine, inspect

# %% [markdown]
# ### 파일 불러오기

# %%
# # 모든 행과 열을 출력하도록 설정
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# # 기본 설정으로 되돌리기
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
import pandas as pd
# 구글드라이브 연동
from google.colab import drive
drive.mount("/content/gdrive")

# %cd /content/gdrive/MyDrive/Colab Notebooks/analysis_edu/03. 데이터베이스 이해 및 ETL 실습

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/analysis_edu/03. 데이터베이스 이해 및 ETL 실습'

# %% [markdown]
# # 1. 데이터 불러오기

# %% [markdown]
# ### 1.1. 상대경로와 절대경로

# %%
# 상대경로: 폴더구조가 안깨진다
relativePath = "../dataset/kopo_product_volume.csv"
selloutData = pd.read_csv( relativePath )

# 절대경로
absPath = "/content/gdrive/MyDrive/Colab Notebooks/analysis_edu/dataset/kopo_product_volume.csv"
absData = pd.read_csv(absPath)
absData

# github 활용 데이터 불러오기
gitUrl = "https://raw.githubusercontent.com/hyokwan/python-lecture/master/dataset/kopo_product_volume.csv"
gitKopodata = pd.read_csv(gitUrl)

# %% [markdown]
# ### 2. MySQL 에 데이터 저장

# %%
selloutData = pd.read_csv("../dataset/kopo_product_volume.csv")
### 데이터베이스 연결 정보 생성
### f 문자열 포맷 이해코드
name = "haiteam"
hostname = "127.0.0.1"
ipAddresss = f"{name}@{hostname}"
userId = "kopouser"
userPw = "kopouser"
host = "13.124.134.168"
port = "3306"
database = "kodb"
myAwsMysqlUrl = f"mysql+mysqlconnector://{userId}:{userPw}@{host}:{port}/{database}"
### 데이터 베이스 접속 엔진생성
engineMySQLAws = create_engine( myAwsMysqlUrl )
tableName = "all_sellout_김효관"
selloutData.to_sql(name = tableName,
                   con = engineMySQLAws,
                   if_exists = "replace", index=False)
selectSql = """
SELECT REGIONID,
    SUM(VOLUME) AS SUM_VOLUME
FROM all_sellout_김효관
GROUP BY REGIONID
"""
selloutMySQL = pd.read_sql_query(sql = selectSql, con = engineMySQLAws)
selloutMySQL

pd.read_table("KOPO_PRODUCT_VOLUME", CON...)

# %%
selectSql = """
SELECT REGIONID,
    SUM(VOLUME) AS SUM_VOLUME
FROM all_sellout_김효관
GROUP BY REGIONID
"""
selloutMySQL = pd.read_sql_query(sql = selectSql, con = engineMySQLAws)
selloutMySQL

pd.read_table("KOPO_PRODUCT_VOLUME", CON...)

# %%
inspectorMySql = inspect(engineMySQLAws)

# %%
inspectorMySql.get_table_names()
# Out:
# ['KOPO_PRODUCT_VOLUME_20240726',
#  'KOPO_PRODUCT_VOLUME_HSI',
#  'all_sellout_강경수',
#  'all_sellout_김시현',
#  'all_sellout_김효관',
#  'all_sellout_박세은',
#  'all_sellout_유소영',
#  'all_sellout_이민식',
#  'all_sellout_이재준']

# %%
type(selloutMySQL)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 데이터베이스 실습 전
# 설치한 데이터베이스에 kopo_product_volume.csv
# 데이터를 저장합니다.
# (데이터베이스 기능 활용!)
