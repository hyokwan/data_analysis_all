# %%
import pandas as pd

# %% [markdown]
# ### 1. 공공데이터 포털 파일데이터 불러오기

# %%
houseDataUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002554243&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR_20211231"

# %%
try:
    houseDataDf = pd.read_csv(houseDataUrl)
except Exception as e:
    print(e)
    houseDataDf = pd.read_csv(houseDataUrl, encoding="ms949")
# Out:
# 'utf-8' codec can't decode byte 0xbf in position 0: invalid start byte

# %%
houseDataDf.tail(10)
# Out:
#        연도   월  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  대구소득대비 주택가격 비율  \
# 203  2021   2            6.84            9.03            6.77            6.77
# 204  2021   3            6.96            9.25            6.42            6.92
# 205  2021   4            7.01            9.09            6.77            7.30
# 206  2021   5            7.05            8.98            7.03            7.22
# 207  2021   6            6.79            8.79            6.83            6.69
# 208  2021   7            6.98            9.11            7.68            6.82
# 209  2021   8            6.74            8.41            7.32            7.08
# 210  2021   9            6.70            8.76            7.75            6.99
# 211  2021  10            6.69            8.55            6.91            7.67
# 212  2021  11            7.10            0.00           10.75           15.29
#
#      인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  울산소득대비 주택가격 비율  ...  \
# ...

# %% [markdown]
# ### [실습] 우편번호 검색 후 데이터 불러오기

# %%
postCodeUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002336443&fileDetailSn=1&dataNm=%ED%86%B5%EA%B3%84%EC%B2%AD_%EB%82%98%EB%9D%BC%ED%86%B5%EA%B3%84_%EC%9A%B0%ED%8E%B8%EB%B2%88%ED%98%B8_20211110"

# %%
postCodeDf = pd.read_csv(postCodeUrl, encoding="ms949")
postCodeDf

# %% [markdown]
# ### 2. 국가통계포털(kosis) 데이터 수집

# %%
koreaPersonCntUrl = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MjUzMTdiMjcyZjQwY2VkMWJkY2RkYTRmZDkwMWQ3ZGY=&itmId=T20+T21+T22+&objL1=00+11+26+27+28+29+30+31+36+41+51+43+44+52+46+47+48+50+&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&newEstPrdCnt=12&orgId=101&tblId=DT_1B040A3"

# %%
pd.DataFrame( [ {"TBL_NM":"남성", "TBL_VALUE":"여성"},
                {"TBL_NM":"사과", "TBL_VALUE":"배"} ] )
# Out:
#   TBL_NM TBL_VALUE
# 0     남성        여성
# 1     사과         배

# %% [markdown]
# ### 성별 인구수 데이터 수집

# %%
try:
    koreadPersonCntDf = pd.read_json(koreaPersonCntUrl)
except Exception as e:
    print(e)
    koreadPersonCntDf = pd.read_json(koreaPersonCntUrl, encoding="ms949")

# %%
koreadPersonCntDf.shape
koreadPersonCntDf
# Out:
#                 TBL_NM  PRD_DE      TBL_ID ITM_NM        ITM_NM_ENG ITM_ID  \
# 0    행정구역(시군구)별 성별 인구수  202308  DT_1B040A3   총인구수   Koreans (Total)    T20
# 1    행정구역(시군구)별 성별 인구수  202309  DT_1B040A3   총인구수   Koreans (Total)    T20
# 2    행정구역(시군구)별 성별 인구수  202310  DT_1B040A3   총인구수   Koreans (Total)    T20
# 3    행정구역(시군구)별 성별 인구수  202311  DT_1B040A3   총인구수   Koreans (Total)    T20
# 4    행정구역(시군구)별 성별 인구수  202312  DT_1B040A3   총인구수   Koreans (Total)    T20
# ..                 ...     ...         ...    ...               ...    ...
# 643  행정구역(시군구)별 성별 인구수  202403  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 644  행정구역(시군구)별 성별 인구수  202404  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 645  행정구역(시군구)별 성별 인구수  202405  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 646  행정구역(시군구)별 성별 인구수  202406  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 647  행정구역(시군구)별 성별 인구수  202407  DT_1B040A3  여자인구수  Koreans (Female)    T22
#
# ...

# %% [markdown]
# ### [실습] 소비자물가지수 수집

# %%
xmlUrl = "https://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev?serviceKey=https://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev?serviceKey=서비스키&LAWD_CD=11110&DEAL_YMD=202407&pageNo=1&numOfRows=10&LAWD_CD=11110&DEAL_YMD=202407&pageNo=1&numOfRows=10"

# %%
priceRatioUrl = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MjUzMTdiMjcyZjQwY2VkMWJkY2RkYTRmZDkwMWQ3ZGY=&itmId=T+&objL1=ALL&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&newEstPrdCnt=3&orgId=101&tblId=INH_1J22003"
try:
    priceRatioDf = pd.read_json(priceRatioUrl)
except Exception as e:
    print(e)
    priceRatioDf = pd.read_json(priceRatioUrl, encoding="ms949")
priceRatioDf

# %% [markdown]
# ### 3. 공공데이터포탈 XML 데이터 수집

# %%
# # 수집전략
# rowList = []
# columnList = []
# # 1개 행의 데이터를 하나씩 순차적으로 columnList에 저장
# columnList.append( 82500 )
# columnList.append( 2021 )
# # 1개 행 저장 완료 시 rowList 에 저장
# rowList.append( columnList )
# columnList = []
# # 1개 행의 데이터를 하나씩 순차적으로 columnList에 저장
# columnList.append( 52500 )
# columnList.append( 2020 )
# # 1개 행 저장 완료 시 rowList 에 저장
# rowList.append( columnList )
# columnList = []
# pd.DataFrame( rowList )

# %%
import requests
from lxml import html
import bs4
# for dealYearMonth .. 반복
# for eachLawCode in range(lawCodeList): 반복:
aptTradeDataUrl = f"http://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&LAWD_CD=11110&DEAL_YMD=202407&pageNo=1&numOfRows=10"
resp = requests.get(aptTradeDataUrl)
xmlObj = bs4.BeautifulSoup( resp.text, "lxml-xml")

rowList = []
columnList = []
columnNameList = []

itemTag = xmlObj.find(name="items")
itemList = itemTag.findAll(name="item")
for j in range(0, len(itemList)):
    #itemList 한개를 가지고 rowList 만들어보자!
    eachRow = itemList[j]
    allColumns = eachRow.findAll()
    # 전체컬럼 데이터를 columnList에 저장한다
    for i in range(0, len(allColumns)):
        eachColumnValue = allColumns[i].text
        columnList.append(eachColumnValue)
        # 첫번째 행을 돌때만 column정보를 수집해서 저장
        if j == 0:
            columnNameList.append( allColumns[i].name )
    rowList.append( columnList)
    columnList = []
aptTradeDf = pd.DataFrame( rowList, columns = columnNameList  )
aptTradeDf

# %%
aptTradeDf = pd.DataFrame( rowList, columns = columnNameList  )

# %%
aptTradeDf
# Out:
#   aptDong       aptNm      aptSeq bonbun bubun buildYear buyerGbn cdealDay  \
# 0               창신쌍용2    11110-91   0703  0000      1993       개인
# 1               창신쌍용2    11110-91   0703  0000      1993       개인
# 2                  현대    11110-90   0082  0000      2000       개인
# 3                  현대    11110-90   0082  0000      2000       개인
# 4            종로중흥S클래스  11110-2339   0202  0003      2013       개인
# 5                  현대    11110-90   0082  0000      2000       개인
# 6               창신쌍용2    11110-91   0703  0000      1993       개인
# 7          경희궁자이(3단지)  11110-2446   0233  0000      2017       개인
# 8            종로중흥S클래스  11110-2339   0202  0003      2013       개인
# 9             인왕산아이파크  11110-2212   0060  0000      2008       개인
#
#   cdealType dealAmount  ... roadNmBonbun roadNmBubun roadNmCd roadNmSeq  \
# 0               59,000  ...        00198       00000  4100020        02
# 1               64,000  ...        00198       00000  4100020        02
# ...

# %% [markdown]
# # 디버깅 코드

# %%
### 아마트 실거래가 데이터 수집 코드
from lxml import html
import bs4
aptTradeDataUrl = "http://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev?serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D&LAWD_CD=11110&DEAL_YMD=202407&pageNo=1&numOfRows=10"
resp = requests.get(aptTradeDataUrl)
xmlObj = bs4.BeautifulSoup( resp.text, "lxml-xml")
# items을 찾아라!!!
# item이 각 행의 데이터셋이니깐 columnList에 저장하자!

rowList = []
columnList = []
columnNameList = []

itemTag = xmlObj.find(name="items")
itemList = itemTag.findAll(name="item")
# for j in range(0, len(itemList)):
j = 0
#itemList 한개를 가지고 rowList 만들어보자!
eachRow = itemList[j]
allColumns = eachRow.findAll()
# 전체컬럼 데이터를 columnList에 저장한다

# %%
i=0

# %%
# for i in range(0, len(allColumns)):
eachColumnValue = allColumns[i].text
columnList.append(eachColumnValue)

if j == 0:
    columnNameList.append( allColumns[i].name )
